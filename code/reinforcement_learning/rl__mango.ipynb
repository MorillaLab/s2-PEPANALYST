# %%
from libs import *
from utilities import *

from Bio import SeqIO
import re
import pandas as pd
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Seq import Seq

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, optimizers
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Sequential, optimizers, losses, regularizers
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay



import warnings
warnings.filterwarnings("ignore")

# %%
from Bio import SeqIO
import pandas as pd
import numpy as np

# Hydrophobicity scale (Kyte-Doolittle)
hydro_scale = {
    'A': 1.8, 'R': -4.5, 'N': -3.5, 'D': -3.5, 'C': 2.5,
    'Q': -3.5, 'E': -3.5, 'G': -0.4, 'H': -3.2, 'I': 4.5,
    'L': 3.8, 'K': -3.9, 'M': 1.9, 'F': 2.8, 'P': -1.6,
    'S': -0.8, 'T': -0.7, 'W': -0.9, 'Y': -1.3, 'V': 4.2
}

def extract_features(fasta_file):
    records = list(SeqIO.parse(fasta_file, "fasta"))
    features = []

    for record in records:
        seq = str(record.seq).upper()
        length = len(seq)

        # Amino acid composition
        counts = {aa: seq.count(aa) for aa in set(seq)}
        freq = {aa: counts.get(aa, 0) / length for aa in hydro_scale.keys()}

        # Hydrophobicity
        hydrophobicity = np.mean([hydro_scale.get(aa, 0) for aa in seq])

        # Cysteine count and pattern
        cysteine_count = seq.count('C')

        # Basic composition metrics
        gc_content = freq['G'] + freq['C']
        charge = freq['K'] + freq['R'] - freq['D'] - freq['E']
        aromaticity = freq['F'] + freq['Y'] + freq['W']

        # Motif checks (example: dibasic protease sites)
        has_dibasic_site = any(x in seq for x in ['KR', 'RR', 'RK'])

        features.append({
            'length': length,
            'hydrophobicity': hydrophobicity,
            'cysteine_count': cysteine_count,
            'gc_content': gc_content,
            'charge': charge,
            'aromaticity': aromaticity,
            'has_dibasic_site': int(has_dibasic_site),
            **freq
        })

    df = pd.DataFrame(features)
    return df

# Example usage
if __name__ == "__main__":
    df_new = extract_features("mango_data.fasta")
    df_new.to_csv("sspeptide_features.csv", index=False)

# %% [markdown]
# ## Load data

# %%
df_new.head()
# Out:
#    length  hydrophobicity  cysteine_count  gc_content    charge  aromaticity  \
# 0     195       -0.830256               5    0.097436  0.076923     0.015385
# 1      98       -0.502041               4    0.153061 -0.030612     0.091837
# 2     196       -0.379082               5    0.142857 -0.025510     0.112245
# 3      80       -1.118750               1    0.012500 -0.062500     0.075000
# 4     177       -0.590395               3    0.045198  0.096045     0.084746
#
#    has_dibasic_site         A         R         N  ...         L         K  \
# 0                 1  0.066667  0.066667  0.025641  ...  0.071795  0.138462
# 1                 0  0.030612  0.061224  0.010204  ...  0.061224  0.061224
# 2                 1  0.030612  0.051020  0.035714  ...  0.081633  0.056122
# 3                 1  0.050000  0.062500  0.100000  ...  0.087500  0.075000
# 4                 1  0.045198  0.039548  0.028249  ...  0.084746  0.163842
#
#           M         F         P         S         T         W         Y  \
# 0  0.041026  0.015385  0.046154  0.087179  0.046154  0.000000  0.000000
# 1  0.020408  0.051020  0.030612  0.091837  0.030612  0.010204  0.030612
# 2  0.025510  0.061224  0.030612  0.086735  0.035714  0.010204  0.040816
# 3  0.037500  0.037500  0.012500  0.075000  0.012500  0.012500  0.025000
# 4  0.050847  0.050847  0.045198  0.112994  0.050847  0.011299  0.022599
#
#           V
# 0  0.061538
# 1  0.071429
# 2  0.056122
# 3  0.012500
# 4  0.056497
#
# [5 rows x 27 columns]

# %%
result_signalp_mango = resultSignalP("../mango_signalp/prediction_results.txt")

# %%
df_new.columns.tolist()
# Out:
# ['length',
#  'hydrophobicity',
#  'cysteine_count',
#  'gc_content',
#  'charge',
#  'aromaticity',
#  'has_dibasic_site',
#  'A',
#  'R',
#  'N',
#  'D',
#  'C',
#  'Q',
#  'E',
#  'G',
#  'H',
#  'I',
#  'L',
#  'K',
#  'M',
#  'F',
#  'P',
#  'S',
#  'T',
#  'W',
#  'Y',
#  'V']

# %%
numeric_cols = df_new.select_dtypes(include=[float, int]).columns.tolist()
scaler = StandardScaler()
df_standardized = df_new.copy()
df_standardized[numeric_cols] = scaler.fit_transform(df_new[numeric_cols])

print("✅ Normalization done!")
print(df_standardized.head())
# Out:
# ✅ Normalization done!
#      length  hydrophobicity  cysteine_count  gc_content    charge  \
# 0  1.443114       -1.225879        0.726159    0.364855  1.021051
# 1 -0.966081       -0.479074        0.365935    1.858607 -0.771797
# 2  1.467951       -0.199298        0.726159    1.584589 -0.686735
# 3 -1.413148       -1.882303       -0.714737   -1.915997 -1.303436
# 4  0.996047       -0.680111        0.005711   -1.037938  1.339858
#
#    aromaticity  has_dibasic_site         A         R         N  ...         L  \
# 0    -2.027132          0.608035 -0.066382  0.424907 -0.809853  ... -0.638750
# 1     0.247046         -1.644642 -1.217304  0.231287 -1.546049  ... -0.949969
# 2     0.854116          0.608035 -1.217304 -0.131750 -0.329453  ... -0.349100
# 3    -0.253786          0.608035 -0.598412  0.276667  2.736369  ... -0.176350
# 4     0.036115          0.608035 -0.751709 -0.539910 -0.685496  ... -0.257442
#
#           K         M         F         P         S         T         W  \
# 0  1.989750  0.658649 -1.250166 -0.045791  0.001295 -0.157973 -1.050313
# 1 -0.284739 -0.585547  0.318360 -0.556336  0.129697 -0.850261 -0.194219
# 2 -0.434985 -0.277656  0.767497 -0.556336 -0.010968 -0.622995 -0.194219
# 3  0.120925  0.445888 -0.276747 -1.151327 -0.334498 -1.657055 -0.001599
# 4  2.737153  1.251363  0.310747 -0.077199  0.713020  0.051100 -0.102322
#
#           Y         V
# 0 -1.571567 -0.106115
# 1  0.195522  0.270144
# 2  0.784552 -0.312162
# 3 -0.128444 -1.971733
# 4 -0.267049 -0.297906
#
# [5 rows x 27 columns]

# %%
label_mango,sequence_mango = readFastaFiles("mango_data.fasta")

# %%
len(sequence_mango)
# Out:
# 5046

# %%
states = df_new.to_numpy().astype(np.float32)

# %%
states[0]
# Out:
# array([ 1.9500000e+02, -8.3025640e-01,  5.0000000e+00,  9.7435899e-02,
#         7.6923080e-02,  1.5384615e-02,  1.0000000e+00,  6.6666670e-02,
#         6.6666670e-02,  2.5641026e-02,  5.1282052e-02,  2.5641026e-02,
#         5.1282052e-02,  7.6923080e-02,  7.1794875e-02,  2.0512821e-02,
#         3.5897437e-02,  7.1794875e-02,  1.3846155e-01,  4.1025642e-02,
#         1.5384615e-02,  4.6153847e-02,  8.7179489e-02,  4.6153847e-02,
#         0.0000000e+00,  0.0000000e+00,  6.1538462e-02], dtype=float32)

# %%
states.shape
# Out:
# (5046, 27)

# %%
result_signalp_mango = resultSignalP("../mango_signalp/prediction_results.txt")

# %%
len(result_signalp_mango)
# Out:
# 5046

# %%
unique, counts = np.unique(result_signalp_mango, return_counts=True)

# %%
#tape_data
mango_ebedding = np.load('sequence_mango.npy')

# %%
#ESM
embed2_mango = torch.load('embed2_mango.pt')

# %%
numpy_array_list = [tensor.numpy() for tensor in embed2_mango]
numpy_embed2_mango = np.array(numpy_array_list)

# %%
numpy_embed2_mango.shape
# Out:
# (5046, 1, 1280)

# %%
mango_ebedding2 = numpy_embed2_mango.reshape(numpy_embed2_mango.shape[0],numpy_embed2_mango.shape[2])

# %%
mango_ebedding2.shape
# Out:
# (5046, 1280)

# %%
len(embed2_mango)
# Out:
# 5046

# %%
embedding_padded = np.concatenate((mango_ebedding, np.zeros((mango_ebedding.shape[0],16))), axis=1)
embedding2_padded = np.concatenate((mango_ebedding2, np.zeros((mango_ebedding2.shape[0],16))), axis=1)

# %%
shape_unit=28
embedding_images=np.reshape(embedding_padded,(embedding_padded.shape[0],shape_unit,shape_unit))

print(embedding_images.shape)
# Out:
# (5046, 28, 28)

# %%
shape_unit=36
embedding2_images=np.reshape(embedding2_padded,(embedding2_padded.shape[0],shape_unit,shape_unit))

print(embedding2_images.shape)
# Out:
# (5046, 36, 36)

# %%
#embedding_geotop = geotop_analysis(embedding_images)

# %%
#28*28
embedding_geotop = np.load("embedding_geotop_mango.npz")

# %%
#36*36
#embedding2_geotop = geotop_analysis(embedding2_images)

# %%
embedding2_geotop = np.load("embedding2_geotop_mango.npz")

# %%
embedding_geotop = [embedding_geotop['arr_'+str(i)] for i in range(len(embedding_geotop))]
embedding2_geotop = [embedding2_geotop['arr_'+str(i)] for i in range(len(embedding2_geotop))]

# %%
len(embedding2_geotop)
# Out:
# 5046

# %% [markdown]
# # Trainning

# %% [markdown]
# ### Tape and Geotop

# %%
dgms = gdr.DiagramSelector(use=True, point_type='finite').fit_transform(embedding_geotop)

# %%
dim = 1024
result = concate_embedding_geotop(mango_ebedding,dgms,dim)

# %%
#splitting the dataset
num_samples = len(result)
num_train_samples = int(0.8 * num_samples)  # 80% for training, 20% for testing

# Split data into training and testing sets
train_data, test_data = result[:num_train_samples], result[num_train_samples:]

# %%
shape_unit=32
std_scale = skp.StandardScaler().fit(train_data)
X_normalized = std_scale.transform(train_data)
train_data = np.reshape(X_normalized,(X_normalized.shape[0],shape_unit,shape_unit))

# %%
std_scale = skp.StandardScaler().fit(test_data)
X_normalized = std_scale.transform(test_data)
test_data=np.reshape(X_normalized,(X_normalized.shape[0],shape_unit,shape_unit))

# %%
train_data_tape = np.expand_dims(train_data, -1)
test_data_tape = np.expand_dims(test_data, -1)

# %% [markdown]
# ### ESM and Geotop

# %%
dgms = gdr.DiagramSelector(use=True, point_type='finite').fit_transform(embedding2_geotop)

# %%
dim = 1681
result = concate_embedding_geotop(mango_ebedding2,dgms,dim)

# %%
len(result)
# Out:
# 5046

# %%
#splitting the dataset
#num_samples = len(result)
#num_train_samples = int(0.8 * num_samples)  # 80% for training, 20% for testing

# Split data into training and testing sets
train_data, test_data = result[:num_train_samples], result[num_train_samples:]
#train_labels, test_labels = result_signalp_mango[:num_train_samples], result_signalp_mango[num_train_samples:]

# %%
shape_unit=41
std_scale = skp.StandardScaler().fit(train_data)
X_normalized = std_scale.transform(train_data)
train_data=np.reshape(X_normalized,(X_normalized.shape[0],shape_unit,shape_unit))

# %%
std_scale = skp.StandardScaler().fit(test_data)
X_normalized = std_scale.transform(test_data)
test_data=np.reshape(X_normalized,(X_normalized.shape[0],shape_unit,shape_unit))

# %%
train_data_esm = np.expand_dims(train_data, -1)
test_data_esm = np.expand_dims(test_data, -1)

# %%
len(test_data_esm)
# Out:
# 1010

# %%
unique, counts = np.unique(y_train, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[   0 3790]
#  [   1  246]]

# %%
unique, counts = np.unique(y_test, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[  0 938]
#  [  1  72]]

# %% [markdown]
# ### Label

# %%
train_labels, test_labels = result_signalp_mango[:num_train_samples], result_signalp_mango[num_train_samples:]

# %%
y_train = np.array(train_labels)
y_test = np.array(test_labels)

# %% [markdown]
# ### state

# %%
len(states)
# Out:
# 5046

# %%
states_train, states_test = states[:num_train_samples], states[num_train_samples:]

# %%
num_train_samples
# Out:
# 4036

# %%
state_dim = 9

# %%
states_test.shape
# Out:
# (1010, 27)

# %% [markdown]
# ## Reinforcement Learning

# %%
# hyperparameters

# %%
n_pretrain_epochs = 50
batch_size_pretrain = 64
n_episodes = 70 #200
gamma = 0.99
policy_lr = 1e-4
value_lr = 1e-4
ent_coef = 0.02
print_every = 10
eps = 1e-8

# %%
#Policy network

# %%
class PolicyNetwork(tf.keras.Model):
    def __init__(self, state_dim, hidden=(128, 64), dropout_rate=0.1):
        super().__init__()
        self.norm = layers.LayerNormalization()
        self.h1 = layers.Dense(hidden[0], activation=tf.nn.gelu, kernel_initializer="he_normal")
        self.do1 = layers.Dropout(dropout_rate)
        self.h2 = layers.Dense(hidden[1], activation=tf.nn.gelu, kernel_initializer="he_normal")
        self.do2 = layers.Dropout(dropout_rate)
        self.logit = layers.Dense(1, activation=None, kernel_initializer="glorot_uniform")

    def call(self, x, training=False):
        x = self.norm(x)
        x = self.h1(x); x = self.do1(x, training=training)
        x = self.h2(x); x = self.do2(x, training=training)
        return self.logit(x)

    @tf.function
    def sample(self, x, training=False, eps=1e-8):
        logit = self(x, training=training)
        p = tf.sigmoid(tf.clip_by_value(logit, -5.0, 5.0))
        u = tf.random.uniform(tf.shape(p))
        action = tf.cast(u < p, tf.float32)
        logp = action * tf.math.log(p + eps) + (1.0 - action) * tf.math.log(1.0 - p + eps)
        entropy = -(p * tf.math.log(p + eps) + (1.0 - p) * tf.math.log(1.0 - p + eps))
        return action, tf.reshape(logp, (-1,)), tf.reshape(entropy, (-1,)), p

# %%
# Value network -> critic network

# %%
class ValueNetwork(tf.keras.Model):
    def __init__(self, state_dim, hidden=(128, 64), dropout_rate=0.1):
        super().__init__()
        self.norm = layers.LayerNormalization()
        self.h1 = layers.Dense(hidden[0], activation=tf.nn.gelu, kernel_initializer="he_normal")
        self.do1 = layers.Dropout(dropout_rate)
        self.h2 = layers.Dense(hidden[1], activation=tf.nn.gelu, kernel_initializer="he_normal")
        self.do2 = layers.Dropout(dropout_rate)
        self.v_out = layers.Dense(1, activation=None, kernel_initializer="glorot_uniform")

    def call(self, x, training=False):
        x = self.norm(x)
        x = self.h1(x); x = self.do1(x, training=training)
        x = self.h2(x); x = self.do2(x, training=training)
        return self.v_out(x)

# %%
# losses and optmizers

# %%
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=False, reduction=tf.keras.losses.Reduction.NONE)
policy_optimizer = optimizers.Adam(policy_lr, clipnorm=1.0)
value_optimizer = optimizers.Adam(value_lr, clipnorm=1.0)
value_loss_fn = tf.keras.losses.MeanSquaredError()

# %%
#trainning the classifier

# %%
dim_ESM = train_data_esm.shape[1:3]
dim_TAPE = train_data_tape.shape[1:3]

model_trainning_saving(dim_ESM, n_pretrain_epochs, "classifier_ESM",
                                        train_data_esm, y_train,
                                        test_data_esm, y_test)

model_trainning_saving(dim_TAPE, n_pretrain_epochs, "classifier_TAPE",
                                         train_data_tape, y_train,
                                         test_data_tape, y_test)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 41, 41, 8)         80
#
#  average_pooling2d_18 (Aver  (None, 20, 20, 8)         0
#  agePooling2D)
#
#  conv2d_19 (Conv2D)          (None, 20, 20, 16)        1168
#
#  average_pooling2d_19 (Aver  (None, 10, 10, 16)        0
#  agePooling2D)
#
#  conv2d_20 (Conv2D)          (None, 10, 10, 32)        4640
#
#  average_pooling2d_20 (Aver  (None, 5, 5, 32)          0
#  agePooling2D)
#
#  flatten_6 (Flatten)         (None, 800)               0
#
#  dense_41 (Dense)            (None, 128)               102528
#
#  dense_42 (Dense)            (None, 64)                8256
#
#  dense_43 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 116737 (456.00 KB)
# Trainable params: 116737 (456.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 64/64 [==============================] - 3s 29ms/step - loss: 0.2884 - accuracy: 0.9390 - val_loss: 0.2767 - val_accuracy: 0.9287
# Epoch 2/50
# 64/64 [==============================] - 1s 23ms/step - loss: 0.2401 - accuracy: 0.9390 - val_loss: 0.2507 - val_accuracy: 0.9287
# Epoch 3/50
# 64/64 [==============================] - 1s 16ms/step - loss: 0.1666 - accuracy: 0.9450 - val_loss: 0.1792 - val_accuracy: 0.9446
# Epoch 4/50
# 64/64 [==============================] - 1s 17ms/step - loss: 0.1350 - accuracy: 0.9621 - val_loss: 0.1403 - val_accuracy: 0.9554
# Epoch 5/50
# 64/64 [==============================] - 1s 23ms/step - loss: 0.1168 - accuracy: 0.9673 - val_loss: 0.1328 - val_accuracy: 0.9564
# Epoch 6/50
# 64/64 [==============================] - 2s 24ms/step - loss: 0.1107 - accuracy: 0.9690 - val_loss: 0.1272 - val_accuracy: 0.9604
# Epoch 7/50
# 64/64 [==============================] - 2s 26ms/step - loss: 0.1031 - accuracy: 0.9710 - val_loss: 0.1310 - val_accuracy: 0.9604
# Epoch 8/50
# 64/64 [==============================] - 1s 23ms/step - loss: 0.0960 - accuracy: 0.9715 - val_loss: 0.1235 - val_accuracy: 0.9604
# Epoch 9/50
# 64/64 [==============================] - 1s 19ms/step - loss: 0.0910 - accuracy: 0.9750 - val_loss: 0.1258 - val_accuracy: 0.9584
# Epoch 10/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.0838 - accuracy: 0.9770 - val_loss: 0.1177 - val_accuracy: 0.9644
# Epoch 11/50
# 64/64 [==============================] - 2s 23ms/step - loss: 0.0812 - accuracy: 0.9772 - val_loss: 0.1131 - val_accuracy: 0.9693
# Epoch 12/50
# 64/64 [==============================] - 1s 20ms/step - loss: 0.0770 - accuracy: 0.9804 - val_loss: 0.1492 - val_accuracy: 0.9564
# Epoch 13/50
# 64/64 [==============================] - 1s 17ms/step - loss: 0.0714 - accuracy: 0.9819 - val_loss: 0.1137 - val_accuracy: 0.9723
# Epoch 14/50
# 64/64 [==============================] - 1s 17ms/step - loss: 0.0647 - accuracy: 0.9824 - val_loss: 0.1239 - val_accuracy: 0.9733
# Epoch 15/50
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0596 - accuracy: 0.9851 - val_loss: 0.1199 - val_accuracy: 0.9683
# Epoch 16/50
# 64/64 [==============================] - 1s 19ms/step - loss: 0.0592 - accuracy: 0.9836 - val_loss: 0.1350 - val_accuracy: 0.9663
# Epoch 17/50
# 64/64 [==============================] - 1s 22ms/step - loss: 0.0601 - accuracy: 0.9824 - val_loss: 0.1209 - val_accuracy: 0.9713
# Epoch 18/50
# 64/64 [==============================] - 1s 17ms/step - loss: 0.0524 - accuracy: 0.9874 - val_loss: 0.1235 - val_accuracy: 0.9683
# Epoch 19/50
# 64/64 [==============================] - 2s 31ms/step - loss: 0.0499 - accuracy: 0.9876 - val_loss: 0.1182 - val_accuracy: 0.9693
# Epoch 20/50
# 64/64 [==============================] - 1s 21ms/step - loss: 0.0413 - accuracy: 0.9916 - val_loss: 0.1325 - val_accuracy: 0.9673
# Epoch 21/50
# 64/64 [==============================] - 1s 19ms/step - loss: 0.0405 - accuracy: 0.9903 - val_loss: 0.1279 - val_accuracy: 0.9693
# Epoch 22/50
# 64/64 [==============================] - 2s 29ms/step - loss: 0.0341 - accuracy: 0.9933 - val_loss: 0.1684 - val_accuracy: 0.9634
# Epoch 23/50
# 64/64 [==============================] - 2s 25ms/step - loss: 0.0376 - accuracy: 0.9923 - val_loss: 0.1410 - val_accuracy: 0.9634
# Epoch 24/50
# 64/64 [==============================] - 1s 17ms/step - loss: 0.0301 - accuracy: 0.9943 - val_loss: 0.1445 - val_accuracy: 0.9614
# Epoch 25/50
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0297 - accuracy: 0.9943 - val_loss: 0.1510 - val_accuracy: 0.9683
# Epoch 26/50
# 64/64 [==============================] - 2s 25ms/step - loss: 0.0302 - accuracy: 0.9938 - val_loss: 0.1318 - val_accuracy: 0.9663
# Epoch 27/50
# 64/64 [==============================] - 1s 19ms/step - loss: 0.0235 - accuracy: 0.9965 - val_loss: 0.1570 - val_accuracy: 0.9673
# Epoch 28/50
# 64/64 [==============================] - 1s 23ms/step - loss: 0.0213 - accuracy: 0.9973 - val_loss: 0.1773 - val_accuracy: 0.9683
# Epoch 29/50
# 64/64 [==============================] - 2s 27ms/step - loss: 0.0235 - accuracy: 0.9968 - val_loss: 0.1414 - val_accuracy: 0.9673
# Epoch 30/50
# 64/64 [==============================] - 1s 17ms/step - loss: 0.0219 - accuracy: 0.9978 - val_loss: 0.1547 - val_accuracy: 0.9723
# Epoch 31/50
# 64/64 [==============================] - 1s 21ms/step - loss: 0.0168 - accuracy: 0.9990 - val_loss: 0.1717 - val_accuracy: 0.9713
# Epoch 32/50
# 64/64 [==============================] - 2s 24ms/step - loss: 0.0157 - accuracy: 0.9993 - val_loss: 0.1850 - val_accuracy: 0.9723
# Epoch 33/50
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0142 - accuracy: 0.9995 - val_loss: 0.1739 - val_accuracy: 0.9723
# Epoch 34/50
# 64/64 [==============================] - 2s 25ms/step - loss: 0.0136 - accuracy: 0.9995 - val_loss: 0.1789 - val_accuracy: 0.9723
# Epoch 35/50
# 64/64 [==============================] - 1s 23ms/step - loss: 0.0129 - accuracy: 0.9995 - val_loss: 0.1727 - val_accuracy: 0.9713
# Epoch 36/50
# 64/64 [==============================] - 1s 22ms/step - loss: 0.0126 - accuracy: 0.9995 - val_loss: 0.1667 - val_accuracy: 0.9693
# Epoch 37/50
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0121 - accuracy: 0.9995 - val_loss: 0.1707 - val_accuracy: 0.9713
# Epoch 38/50
# 64/64 [==============================] - 2s 24ms/step - loss: 0.0119 - accuracy: 0.9995 - val_loss: 0.1723 - val_accuracy: 0.9713
# Epoch 39/50
# 64/64 [==============================] - 2s 28ms/step - loss: 0.0228 - accuracy: 0.9950 - val_loss: 0.1416 - val_accuracy: 0.9663
# Epoch 40/50
# 64/64 [==============================] - 1s 21ms/step - loss: 0.0248 - accuracy: 0.9941 - val_loss: 0.1832 - val_accuracy: 0.9644
# Epoch 41/50
# 64/64 [==============================] - 2s 26ms/step - loss: 0.0226 - accuracy: 0.9943 - val_loss: 0.1783 - val_accuracy: 0.9574
# Epoch 42/50
# 64/64 [==============================] - 1s 18ms/step - loss: 0.0293 - accuracy: 0.9931 - val_loss: 0.1707 - val_accuracy: 0.9733
# Epoch 43/50
# 64/64 [==============================] - 1s 16ms/step - loss: 0.0215 - accuracy: 0.9960 - val_loss: 0.1765 - val_accuracy: 0.9653
# Epoch 44/50
# 64/64 [==============================] - 1s 21ms/step - loss: 0.0138 - accuracy: 0.9990 - val_loss: 0.1939 - val_accuracy: 0.9683
# Epoch 45/50
# 64/64 [==============================] - 1s 10ms/step - loss: 0.0124 - accuracy: 0.9995 - val_loss: 0.1957 - val_accuracy: 0.9703
# Epoch 46/50
# 64/64 [==============================] - 1s 17ms/step - loss: 0.0115 - accuracy: 0.9995 - val_loss: 0.1757 - val_accuracy: 0.9713
# Epoch 47/50
# 64/64 [==============================] - 1s 21ms/step - loss: 0.0108 - accuracy: 0.9995 - val_loss: 0.1915 - val_accuracy: 0.9693
# Epoch 48/50
# 64/64 [==============================] - 1s 13ms/step - loss: 0.0108 - accuracy: 0.9995 - val_loss: 0.1830 - val_accuracy: 0.9693
# Epoch 49/50
# 64/64 [==============================] - 1s 10ms/step - loss: 0.0103 - accuracy: 0.9995 - val_loss: 0.1764 - val_accuracy: 0.9713
# Epoch 50/50
# 64/64 [==============================] - 1s 12ms/step - loss: 0.0100 - accuracy: 0.9995 - val_loss: 0.1741 - val_accuracy: 0.9703
# {'loss': [0.2884211838245392, 0.24010209739208221, 0.1666303426027298, 0.1349804699420929, 0.11684264242649078, 0.11069146543741226, 0.10312046855688095, 0.09598622471094131, 0.09103460609912872, 0.08378776162862778, 0.08117397874593735, 0.07702267915010452, 0.07140695303678513, 0.06470020860433578, 0.05961674451828003, 0.059189848601818085, 0.06012606993317604, 0.052435338497161865, 0.04993860423564911, 0.04129333049058914, 0.04052017256617546, 0.03406311199069023, 0.0375681035220623, 0.030057545751333237, 0.029736647382378578, 0.030226968228816986, 0.023477748036384583, 0.0212850458920002, 0.023491395637392998, 0.02192091755568981, 0.0168415829539299, 0.015728935599327087, 0.01415916346013546, 0.013581115752458572, 0.012893426232039928, 0.012623516842722893, 0.012080119922757149, 0.011851061135530472, 0.02278742752969265, 0.024804769083857536, 0.022646890953183174, 0.029348237439990044, 0.021545369178056717, 0.013805828057229519, 0.012359182350337505, 0.011494947597384453, 0.010848639532923698, 0.010838907212018967, 0.010320681147277355, 0.009966707788407803], 'accuracy': [0.9390485882759094, 0.9390485882759094, 0.9449950456619263, 0.9620912075042725, 0.9672943353652954, 0.9690287709236145, 0.9710109233856201, 0.9715064167976379, 0.9749752283096313, 0.976957380771637, 0.9772051572799683, 0.9804261922836304, 0.9819127917289734, 0.982408344745636, 0.9851337671279907, 0.9836471676826477, 0.982408344745636, 0.9873637557029724, 0.9876114726066589, 0.9915758371353149, 0.9903369545936584, 0.9933102130889893, 0.9923191070556641, 0.9943012595176697, 0.9943012595176697, 0.9938057661056519, 0.9965312480926514, 0.9972745180130005, 0.9967789649963379, 0.9977700710296631, 0.9990088939666748, 0.9992566704750061, 0.9995044469833374, 0.9995044469833374, 0.9995044469833374, 0.9995044469833374, 0.9995044469833374, 0.9995044469833374, 0.9950445890426636, 0.9940535426139832, 0.9943012595176697, 0.993062436580658, 0.9960356950759888, 0.9990088939666748, 0.9995044469833374, 0.9995044469833374, 0.9995044469833374, 0.9995044469833374, 0.9995044469833374, 0.9995044469833374], 'val_loss': [0.27666762471199036, 0.2507290542125702, 0.17924508452415466, 0.1403065323829651, 0.13278880715370178, 0.12721765041351318, 0.13096952438354492, 0.12348832190036774, 0.12582337856292725, 0.11773364990949631, 0.11307652294635773, 0.14918041229248047, 0.11368940770626068, 0.12387370318174362, 0.11989898234605789, 0.13497908413410187, 0.12087445706129074, 0.12353909760713577, 0.11822360754013062, 0.132541686296463, 0.1279272586107254, 0.16841739416122437, 0.14097578823566437, 0.14450348913669586, 0.15096579492092133, 0.13184596598148346, 0.1569652259349823, 0.17734885215759277, 0.14136186242103577, 0.15470345318317413, 0.17165379226207733, 0.1849835216999054, 0.17391985654830933, 0.17894794046878815, 0.172684907913208, 0.16665537655353546, 0.1706564575433731, 0.17233172059059143, 0.14162343740463257, 0.18319250643253326, 0.1783159077167511, 0.17073555290699005, 0.17650412023067474, 0.1938786804676056, 0.19572684168815613, 0.17565971612930298, 0.19148269295692444, 0.18296824395656586, 0.1763538122177124, 0.17409709095954895], 'val_accuracy': [0.9287128448486328, 0.9287128448486328, 0.9445544481277466, 0.9554455280303955, 0.9564356207847595, 0.9603960514068604, 0.9603960514068604, 0.9603960514068604, 0.9584158658981323, 0.9643564224243164, 0.9693069458007812, 0.9564356207847595, 0.9722772240638733, 0.9732673168182373, 0.9683168530464172, 0.9663366079330444, 0.9712871313095093, 0.9683168530464172, 0.9693069458007812, 0.9673267602920532, 0.9693069458007812, 0.9633663296699524, 0.9633663296699524, 0.9613861441612244, 0.9683168530464172, 0.9663366079330444, 0.9673267602920532, 0.9683168530464172, 0.9673267602920532, 0.9722772240638733, 0.9712871313095093, 0.9722772240638733, 0.9722772240638733, 0.9722772240638733, 0.9712871313095093, 0.9693069458007812, 0.9712871313095093, 0.9712871313095093, 0.9663366079330444, 0.9643564224243164, 0.9574257135391235, 0.9732673168182373, 0.9 ...
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_21 (Conv2D)          (None, 32, 32, 8)         80
#
#  average_pooling2d_21 (Aver  (None, 16, 16, 8)         0
#  agePooling2D)
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 16)        1168
#
#  average_pooling2d_22 (Aver  (None, 8, 8, 16)          0
#  agePooling2D)
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 32)          4640
#
#  average_pooling2d_23 (Aver  (None, 4, 4, 32)          0
#  agePooling2D)
#
#  flatten_7 (Flatten)         (None, 512)               0
#
#  dense_44 (Dense)            (None, 128)               65664
#
#  dense_45 (Dense)            (None, 64)                8256
#
#  dense_46 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 79873 (312.00 KB)
# Trainable params: 79873 (312.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 64/64 [==============================] - 3s 28ms/step - loss: 0.3161 - accuracy: 0.9252 - val_loss: 0.2822 - val_accuracy: 0.9287
# Epoch 2/50
# 64/64 [==============================] - 1s 20ms/step - loss: 0.2388 - accuracy: 0.9390 - val_loss: 0.2133 - val_accuracy: 0.9287
# Epoch 3/50
# 64/64 [==============================] - 1s 21ms/step - loss: 0.1777 - accuracy: 0.9480 - val_loss: 0.1641 - val_accuracy: 0.9515
# Epoch 4/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.1511 - accuracy: 0.9556 - val_loss: 0.1625 - val_accuracy: 0.9535
# Epoch 5/50
# 64/64 [==============================] - 1s 14ms/step - loss: 0.1432 - accuracy: 0.9559 - val_loss: 0.1523 - val_accuracy: 0.9535
# Epoch 6/50
# 64/64 [==============================] - 1s 21ms/step - loss: 0.1330 - accuracy: 0.9609 - val_loss: 0.1701 - val_accuracy: 0.9376
# Epoch 7/50
#  1/64 [..............................] - ETA: 0s - loss: 0.1346 - accuracy: 0.9531

# %%
#if the model is already trained, we can load them 
classifier_ESM = load_model("classifier_ESM.h5")
classifier_TAPE = load_model("classifier_TAPE.h5")

# %%
state_dim = states_train.shape[1]
policy = PolicyNetwork(state_dim)
value_net = ValueNetwork(state_dim)

# %%
if y_train.ndim == 1:
    y_train = y_train.reshape(-1, 1)

# %%
#RL loop

# %%
N = len(states_train)

for episode in range(1, n_episodes + 1):
    idx = np.random.permutation(N)
    log_probs_list, rewards_list, chosen_idxs, true_labels, preds_for_acc = [], [], [], [], []

    for i in idx:
        state_sample = tf.convert_to_tensor(states_train[i:i+1], dtype=tf.float32)
        action, logp, entropy, prob = policy.sample(state_sample, training=True, eps=eps)
        log_probs_list.append(logp)

        # Get both classifier predictions
        logits_esm = classifier_ESM(tf.convert_to_tensor(train_data_esm[i:i+1], dtype=tf.float32), training=False)
        logits_tape = classifier_TAPE(tf.convert_to_tensor(train_data_tape[i:i+1], dtype=tf.float32), training=False)
        p_esm = logits_esm
        p_tape = logits_tape

        y_sample = y_train[i:i+1]
        if y_sample.ndim == 1:
            y_sample = y_sample.reshape(-1, 1)

        # Choose classifier based on policy action
        if int(action.numpy().flatten()[0]) == 0:
            chosen_p = p_esm
            other_p = p_tape
        else:
            chosen_p = p_tape
            other_p = p_esm

        # Base reward: accuracy + negative loss
        is_correct = tf.cast(tf.equal(tf.round(chosen_p), y_sample), tf.float32)
        base_reward = -loss_fn(y_sample, chosen_p) + is_correct

        # Relative performance penalty
        diff_penalty = tf.abs(y_sample - chosen_p) - tf.abs(y_sample - other_p)
        reward = base_reward - diff_penalty

        rewards_list.append(tf.reshape(reward, (-1,)))
        preds_for_acc.append(tf.round(chosen_p).numpy().flatten()[0])
        chosen_idxs.append(int(action.numpy().flatten()[0]))
        true_labels.append(y_sample.flatten()[0])

    # --- Discounted rewards ---
    rewards_np = np.array([r.numpy()[0] for r in rewards_list])
    discounted, R = [], 0.0
    for r in reversed(rewards_np):
        R = r + gamma * R
        discounted.insert(0, R)
    discounted = tf.convert_to_tensor(discounted, dtype=tf.float32)
    discounted = (discounted - tf.reduce_mean(discounted)) / (tf.math.reduce_std(discounted) + 1e-8)

    states_batch = tf.convert_to_tensor(states_train[idx], dtype=tf.float32)
    actions_taken = tf.reshape(tf.convert_to_tensor(chosen_idxs, dtype=tf.float32), (-1, 1))

    # ===== Value Update =====
    with tf.GradientTape() as tape_v:
        values = tf.squeeze(value_net(states_batch, training=True), axis=-1)
        v_loss = value_loss_fn(discounted, values)
    v_grads = tape_v.gradient(v_loss, value_net.trainable_variables)
    value_optimizer.apply_gradients(zip(v_grads, value_net.trainable_variables))

    # ===== Policy Update =====
    with tf.GradientTape() as tape_pg:
        logits_batch = policy(states_batch, training=True)
        probs_batch = tf.sigmoid(tf.clip_by_value(logits_batch, -5.0, 5.0))
        logp_batch = actions_taken * tf.math.log(probs_batch + eps) + (1.0 - actions_taken) * tf.math.log(1.0 - probs_batch + eps)
        logp_batch = tf.reshape(logp_batch, (-1,))
        values = tf.squeeze(value_net(states_batch, training=False), axis=-1)
        advantages = discounted - tf.stop_gradient(values)
        advantages = (advantages - tf.reduce_mean(advantages)) / (tf.math.reduce_std(advantages) + 1e-8)
        entropy_batch = -(probs_batch * tf.math.log(probs_batch + eps) + (1.0 - probs_batch) * tf.math.log(1.0 - probs_batch + eps))
        entropy_batch = tf.reshape(entropy_batch, (-1,))
        pg_loss = -tf.reduce_mean(logp_batch * advantages) - ent_coef * tf.reduce_mean(entropy_batch)
    pg_grads = tape_pg.gradient(pg_loss, policy.trainable_variables)
    policy_optimizer.apply_gradients(zip(pg_grads, policy.trainable_variables))

    # --- Logging ---
    avg_reward = np.mean(rewards_np)
    overall_acc = np.mean(np.array(preds_for_acc) == np.array(true_labels))
    mean_prob = tf.reduce_mean(tf.sigmoid(policy(tf.convert_to_tensor(states_train, dtype=tf.float32)))).numpy()

    if episode % print_every == 0 or episode == 1:
        print(f"Episode {episode}/{n_episodes} | avg_reward={avg_reward:.4f} | policy_loss={pg_loss.numpy():.6f} | "
              f"value_loss={v_loss.numpy():.6f} | overall_acc={overall_acc:.4f} | mean_policy_prob={mean_prob:.3f}")

# %%
# Evaluating different models

# %%
def eval_classifier(model, X, y):
    if y.ndim == 1:
        y = y.reshape(-1, 1)
    preds = model.predict(X)
    loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y, preds)).numpy()
    acc = accuracy_score(y, (preds > 0.5).astype(int))
    auc = roc_auc_score(y, preds)
    cm = confusion_matrix(y, (preds > 0.5).astype(int))
    return acc, auc, loss, cm

# %%
#Evaluate policy
def eval_policy(policy, classifier_ESM, classifier_TAPE, X_esm, X_tape, states, y):
    chosen_correct, total = 0, len(y)
    for i in range(total):
        state = tf.convert_to_tensor(states[i:i+1], dtype=tf.float32)
        action, _, _, _ = policy.sample(state, training=False)
        action = int(action.numpy().flatten()[0])

        y_true = y[i]
        p_esm = classifier_ESM.predict(X_esm[i:i+1])[0][0]
        p_tape = classifier_TAPE.predict(X_tape[i:i+1])[0][0]

        chosen_pred = p_esm if action == 0 else p_tape
        chosen_correct += int(round(chosen_pred) == y_true)
    return chosen_correct / total

# %%
def eval_combined_system(policy, classifier_ESM, classifier_TAPE, X_esm, X_tape, states, y):
    all_preds = []
    for i in range(len(y)):
        state = tf.convert_to_tensor(states[i:i+1], dtype=tf.float32)
        action, _, _, _ = policy.sample(state, training=False)
        action = int(action.numpy().flatten()[0])

        if action == 0:
            pred = classifier_ESM.predict(X_esm[i:i+1])[0][0]
        else:
            pred = classifier_TAPE.predict(X_tape[i:i+1])[0][0]
        all_preds.append(pred)

    all_preds = np.array(all_preds)
    acc = accuracy_score(y, (all_preds > 0.5).astype(int))
    auc = roc_auc_score(y, all_preds)
    loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y, all_preds)).numpy()
    cm = confusion_matrix(y, (all_preds > 0.5).astype(int))
    return acc, auc, loss, cm

# %%
acc_esm, auc_esm, loss_esm, cm_esm = eval_classifier(classifier_ESM, test_data_esm, y_test)
acc_tape, auc_tape, loss_tape, cm_tape = eval_classifier(classifier_TAPE, test_data_tape, y_test)

# %%
policy_acc = eval_policy(policy, classifier_ESM, classifier_TAPE, test_data_esm, test_data_tape, states_test, y_test)

# %%
acc_combined, auc_combined, loss_combined, cm_rl = eval_combined_system(policy, classifier_ESM, classifier_TAPE,
                                                                 test_data_esm, test_data_tape, states_test, y_test)

# %%
print("\n==================== Evaluation Summary ====================")
print(f"ESM classifier:      acc={acc_esm:.4f}, auc={auc_esm:.4f}, loss={loss_esm:.4f}")
print(f"TAPE classifier:     acc={acc_tape:.4f}, auc={auc_tape:.4f}, loss={loss_tape:.4f}")
print(f"Policy decision acc: {policy_acc:.4f}")
print(f"Combined system:     acc={acc_combined:.4f}, auc={auc_combined:.4f}, loss={loss_combined:.4f}")
print("============================================================\n")

# %%
#confusion matrix

# %%
disp = ConfusionMatrixDisplay(cm_esm)
disp.plot(cmap='Blues')
plt.savefig("confusion_matrix_esm.png", dpi=300, bbox_inches='tight')

# %%
disp = ConfusionMatrixDisplay(cm_tape)
disp.plot(cmap='Blues')
plt.savefig("confusion_matrix_tape.png", dpi=300, bbox_inches='tight')

# %%
disp = ConfusionMatrixDisplay(cm_rl)
disp.plot(cmap='Blues')
plt.savefig("confusion_matrix_rl.png", dpi=300, bbox_inches='tight')
